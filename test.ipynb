# %% [markdown]
# <a href="https://colab.research.google.com/github/Ansh358/test/blob/main/test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('cancer.csv', encoding=result['encoding'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-2cbe9357e258> in <cell line: 1>()
# ----> 1 df = pd.read_csv('cancer.csv', encoding=result['encoding'])
#
# NameError: name 'result' is not defined

# %%
df.head()
# Out:
#                           TransactionID        Date MobileModel  \
# 0  79397f68-61ed-4ea8-bcb2-f918d4e6c05b  2024-01-06   direction
# 1  4f87d114-f522-4ead-93e3-f336402df6aa  2024-04-05       right
# 2  6750b7d6-dcc5-48c5-a76a-b6fc9d540fe1  2024-02-13      summer
# 3  7da7de95-f772-4cc2-bce0-b0873f98233e  2024-04-17        keep
# 4  469044af-0d60-4d87-af66-c6603e844057  2024-06-02      option
#
#               Brand    Price  UnitsSold  TotalRevenue  CustomerAge  \
# 0         Green Inc  1196.95         85      28002.80           32
# 1   Thomas-Thompson  1010.34         64       2378.82           55
# 2  Sanchez-Williams   400.80         95      31322.56           57
# 3    Greer and Sons   338.60         79      31159.75           46
# 4    Brown and Sons   839.79         41      11523.36           38
#
#   CustomerGender           Location PaymentMethod
# 0         Female          Port Erik        Online
# 1         Female         East Linda   Credit Card
# ...

# %%
df.tail()
# Out:
#                           TransactionID        Date MobileModel  \
# 0  79397f68-61ed-4ea8-bcb2-f918d4e6c05b  2024-01-06   direction
# 1  4f87d114-f522-4ead-93e3-f336402df6aa  2024-04-05       right
# 2  6750b7d6-dcc5-48c5-a76a-b6fc9d540fe1  2024-02-13      summer
# 3  7da7de95-f772-4cc2-bce0-b0873f98233e  2024-04-17        keep
# 4  469044af-0d60-4d87-af66-c6603e844057  2024-06-02      option
#
#               Brand    Price  UnitsSold  TotalRevenue  CustomerAge  \
# 0         Green Inc  1196.95         85      28002.80           32
# 1   Thomas-Thompson  1010.34         64       2378.82           55
# 2  Sanchez-Williams   400.80         95      31322.56           57
# 3    Greer and Sons   338.60         79      31159.75           46
# 4    Brown and Sons   839.79         41      11523.36           38
#
#   CustomerGender           Location PaymentMethod
# 0         Female          Port Erik        Online
# 1         Female         East Linda   Credit Card
# ...

# %%
df.shape
# Out:
# (5, 11)

# %%
df.columns
# Out:
# Index(['TransactionID', 'Date', 'MobileModel', 'Brand', 'Price', 'UnitsSold',
#        'TotalRevenue', 'CustomerAge', 'CustomerGender', 'Location',
#        'PaymentMethod'],
#       dtype='object')

# %%
df.info('TotalRevenue')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   TransactionID   5 non-null      object
#  1   Date            5 non-null      object
#  2   MobileModel     5 non-null      object
#  3   Brand           5 non-null      object
#  4   Price           5 non-null      float64
#  5   UnitsSold       5 non-null      int64
#  6   TotalRevenue    5 non-null      float64
#  7   CustomerAge     5 non-null      int64
#  8   CustomerGender  5 non-null      object
#  9   Location        5 non-null      object
#  10  PaymentMethod   5 non-null      object
# dtypes: float64(2), int64(2), object(7)
# memory usage: 568.0+ bytes

# %%
df.iloc[1:3]
# Out:
#                           TransactionID        Date MobileModel  \
# 1  4f87d114-f522-4ead-93e3-f336402df6aa  2024-04-05       right
# 2  6750b7d6-dcc5-48c5-a76a-b6fc9d540fe1  2024-02-13      summer
#
#               Brand    Price  UnitsSold  TotalRevenue  CustomerAge  \
# 1   Thomas-Thompson  1010.34         64       2378.82           55
# 2  Sanchez-Williams   400.80         95      31322.56           57
#
#   CustomerGender           Location PaymentMethod
# 1         Female         East Linda   Credit Card
# 2           Male  East Angelicastad        Online

# %%
df.describe()
# Out:
#             Price  UnitsSold  TotalRevenue  CustomerAge
# count     5.00000   5.000000      5.000000     5.000000
# mean    757.29600  72.800000  20877.458000    45.600000
# std     376.34024  21.028552  13184.222962    10.737784
# min     338.60000  41.000000   2378.820000    32.000000
# 25%     400.80000  64.000000  11523.360000    38.000000
# 50%     839.79000  79.000000  28002.800000    46.000000
# 75%    1010.34000  85.000000  31159.750000    55.000000
# max    1196.95000  95.000000  31322.560000    57.000000

# %%
plt.figure(figsize=(12,6))
df['TotalRevenue'].value_counts().plot(kind='bar',color='red')
plt.title('Barchart of Sales')
plt.xlabel('MobileModel')
plt.ylabel('Count')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-60d187a4238e> in <cell line: 2>()
#       1 plt.figure(figsize=(12,6))
# ----> 2 df['TotalRevenue'].value_counts().plot(kind='bar',color='red')
#       3 plt.title('Barchart of Sales')
#       4 plt.xlabel('MobileModel')
#       5 plt.ylabel('Count')
#
# NameError: name 'df' is not defined

# %%
plt.figure(figsize=(12,6))
df['Price'].value_counts().plot(kind='bar',color='red')
plt.title('Barchart of price')
plt.xlabel('Price')
plt.ylabel('Count')
plt.show()
